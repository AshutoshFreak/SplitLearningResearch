# %% [markdown]
# - [x]  Train Accuracy & Test Accuracy vs Epochs
# - [x]  Saturated Train Accuracy vs. Num_clients
# - [x]  Saturated Testing Accuracy vs. Num_Clients
# - [x]  Training accuracy vs Each client bar graph
# - [x]  Testing accuracy vs Each client bar graph
# - [x]  Generalising for multiple users
# - [x]  Accuracy per user
# - [x]  Different datasets
# - [x]  All of these for CNN model
# - [ ]  Transfer learning
# - [ ]  Trying on pregnancy data and breast cancer dataset
# - [ ]  Max batch size for each client
# - [ ]  Calculate network overhead and computation per user

# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import torch.nn.functional as F
import matplotlib.pyplot as plt
from math import ceil

# %%
# Device Configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Hyper-parameters
input_size = 1
channels1 = 10
channels2 = 20
fc_size1 = 320
fc_size2 = 50
num_classes = 10
num_epochs = 150
momentum = 0.5
learning_rate = 0.01

# %%
num_clients = 10

# %%
# MNIST dataset

# !wget www.di.ens.fr/~lelarge/MNIST.tar.gz
# !tar -zxvf MNIST.tar.gz ./data

train_dataset = torchvision.datasets.MNIST(root='../../data',
                                           train=True,
                                           transform=transforms.ToTensor()
                                        #    download=True)
                                            )

test_dataset = torchvision.datasets.MNIST(root='../../data',
                                          train=False,
                                          transform=transforms.ToTensor())


train_batch_size = len(train_dataset)//num_clients
train_split = [train_batch_size]*(num_clients-1)
train_split.append(len(train_dataset)-train_batch_size*(num_clients-1))

test_batch_size = len(test_dataset)//num_clients
test_split = [test_batch_size]*(num_clients-1)
test_split.append(len(test_dataset)-test_batch_size*(num_clients-1))

train_datasets = list(torch.utils.data.random_split(train_dataset, train_split))
test_datasets = list(torch.utils.data.random_split(test_dataset, test_split))

# Data loaders
train_loaders = []
for train_dataset in train_datasets:
    train_loaders.append(torch.utils.data.DataLoader(dataset=train_dataset,
                                                batch_size=train_batch_size,
                                                shuffle=True))

test_loaders = []
for test_dataset in test_datasets:
    test_loaders.append(torch.utils.data.DataLoader(dataset=test_dataset,
                                                batch_size=test_batch_size,
                                                shuffle=True))

# %%
examples = iter(test_loaders[0])
example_data, example_targets = examples.next()
print(example_data.shape, example_targets.shape)
# Out:
# torch.Size([1000, 1, 28, 28]) torch.Size([1000])

# %%
for i in range(6):
    plt.subplot(2,3,i+1)
    plt.title(example_targets[i].item())
    plt.imshow(example_data[i][0], cmap='gray')
plt.show()

# %%
class ClientStartCNN(nn.Module):
    def __init__(self, input_size, channels1):
        super(ClientStartCNN, self).__init__()
        self.conv1 = nn.Conv2d(input_size, channels1, kernel_size=5, stride=1)
        

    def forward(self, x):
        x = self.conv1(x)
        x = F.max_pool2d(x, 2)
        x = F.relu(x)
        return x

startModels = []
for i in range(num_clients):
    startModels.append(ClientStartCNN(input_size, channels1).to(device))

# %%
class ServerCNN(nn.Module):
    def __init__(self, channels1, channels2):
        super(ServerCNN, self).__init__()
        # self.input_size = input_size
        # self.l1 = nn.Linear(input_size, hidden_size)
        self.conv2 = nn.Conv2d(channels1, channels2, kernel_size=5, stride=1)
        self.conv2_drop = nn.Dropout2d()
    
    def forward(self, x):
        # out = self.l1(x)
        # out = self.relu(out)
        # out = self.l2(out)
        x = self.conv2(x)
        x = self.conv2_drop(x)
        x = F.max_pool2d(x, 2)
        x = F.relu(x)
        return x

serverModel = ServerCNN(channels1, channels2).to(device)

# %%
class ClientEndCNN(nn.Module):
    def __init__(self, fc_size1, fc_size2, num_classes):
        super(ClientEndCNN, self).__init__()
        #fully connected layer
        self.fc1 = nn.Linear(fc_size1, fc_size2)
        self.fc2 = nn.Linear(fc_size2, num_classes)
        self.fc_size1 = fc_size1
    
    def forward(self, x):
        x = x.view(-1, fc_size1) # Flatten
        x = self.fc1(x)
        x = F.relu(x)
        x = F.dropout(x)
        x = self.fc2(x)
        return x

endModels = []
for i in range(num_clients):
    endModels.append(ClientEndCNN(fc_size1, fc_size2, num_classes).to(device))

# %%
# loss and optimizer
criterion = nn.CrossEntropyLoss()

startOptimizers = []
for i in range(num_clients):
    startOptimizers.append(torch.optim.Adam(startModels[i].parameters(), lr=learning_rate))


serverOptimizer = torch.optim.Adam(serverModel.parameters(), lr=learning_rate)


endOptimizers = []
for i in range(num_clients):
    endOptimizers.append(torch.optim.Adam(endModels[i].parameters(), lr=learning_rate))

# %%
def mergeGrad(params):
    # params = [params_client1,
    #           params_client2,
    #           params_client3
    #           ...
    #          ]
    for col in zip(*params):
        avg = 0
        for param in col:
            avg += param.grad
        avg /= num_clients
        for param in col:
            param.grad = avg.clone()

# %%
# training loop
total_train_acc = []
total_test_acc = []
for epoch in range(num_epochs):
    grads = []
    losses = []
    n_correct = 0
    test_n_correct = 0
    n_samples = []
    n_samples = 0
    test_n_samples = 0
    for client in range(num_clients):
        images, labels = iter(train_loaders[client]).next()
        # images = images.reshape(-1, 784).to(device)
        images = images.to(device)
        labels = labels.to(device)

        ## Forward
        # Forward through starting layers (with client 1)
        activations1 = startModels[client](images)
        remote_activations1 = activations1.detach().requires_grad_(True)      

        # Forward through middle layers (with server) 
        activations2 = serverModel(remote_activations1)
        remote_activations2 = activations2.detach().requires_grad_(True)

        # Forward through ending layers (with client 1)
        outputs = endModels[client](remote_activations2)


        # loss
        loss = criterion(outputs, labels)
        losses.append(loss.item())


        # Calculating Train Accuracy
        with torch.no_grad():
            _, predicted = torch.max(outputs.data, 1)
            n_correct += (predicted == labels).sum().item()
            n_samples += labels.size(0)
        
        # Calculating Test Accuracy
        with torch.no_grad():
            test_images, test_labels = iter(test_loaders[client]).next()
            test_images = test_images.to(device)
            test_labels = test_labels.to(device)

            ## Forward
            # Forward through starting layers (with client 1)
            test_activations1 = startModels[client](test_images)
            test_remote_activations1 = test_activations1.detach().requires_grad_(True) 

            # Forward through middle layers (with server) 
            test_activations2 = serverModel(test_remote_activations1)
            test_remote_activations2 = test_activations2.detach().requires_grad_(True)

            # Forward through ending layers (with client 1)
            test_outputs = endModels[client](test_remote_activations2)

            # value, index
            _, test_predicted = torch.max(test_outputs.data, 1)
            test_n_correct += (test_predicted == test_labels).sum().item()
            test_n_samples += test_labels.size(0)



        # backwards
        startOptimizers[client].zero_grad()
        serverOptimizer.zero_grad()
        endOptimizers[client].zero_grad()

        loss.backward()
        activations2.backward(remote_activations2.grad)
        activations1.backward(remote_activations1.grad)

        startOptimizers[client].step()

        grads.append(serverModel.parameters())
        endOptimizers[client].step()

    mergeGrad(grads)
    serverOptimizer.step()

    total_train_acc.append(100.0 * n_correct / n_samples)
    total_test_acc.append(100.0 * test_n_correct / test_n_samples)
    print(f'Epoch [{epoch+1}/{num_epochs}]: Avg Loss: {sum(losses)/num_clients:.4f}, Total Train Accuracy: {total_train_acc[-1]:.4f}, Total Test Accuracy: {total_test_acc[-1]:.4f}')
# Out:
# Epoch [1/150]: Avg Loss: 2.3087, Total Train Accuracy: 9.4800, Total Test Accuracy: 9.6300
# Epoch [2/150]: Avg Loss: 2.2829, Total Train Accuracy: 15.6950, Total Test Accuracy: 16.3400
# Epoch [3/150]: Avg Loss: 2.2357, Total Train Accuracy: 20.3267, Total Test Accuracy: 19.5500
# Epoch [4/150]: Avg Loss: 2.1533, Total Train Accuracy: 25.9133, Total Test Accuracy: 26.1800
# Epoch [5/150]: Avg Loss: 2.0351, Total Train Accuracy: 31.5333, Total Test Accuracy: 31.4200
# Epoch [6/150]: Avg Loss: 1.8861, Total Train Accuracy: 38.2517, Total Test Accuracy: 37.9700
# Epoch [7/150]: Avg Loss: 1.7273, Total Train Accuracy: 43.3483, Total Test Accuracy: 43.4100
# Epoch [8/150]: Avg Loss: 1.5831, Total Train Accuracy: 49.0583, Total Test Accuracy: 49.3700
# Epoch [9/150]: Avg Loss: 1.4553, Total Train Accuracy: 52.7683, Total Test Accuracy: 52.7800
# Epoch [10/150]: Avg Loss: 1.3375, Total Train Accuracy: 55.9983, Total Test Accuracy: 56.2500
# Epoch [11/150]: Avg Loss: 1.2409, Total Train Accuracy: 58.6000, Total Test Accuracy: 59.5200
# Epoch [12/150]: Avg Loss: 1.1592, Total Train Accuracy: 61.4300, Total Test Accuracy: 62.4400
# Epoch [13/150]: Avg Loss: 1.0925, Total Train Accuracy: 63.9083, Total Test Accuracy: 64.8300
# Epoch [14/150]: Avg Loss: 1.0353, Total Train Accuracy: 65.7067, Total Test Accuracy: 66.6600
# Epoch [15/150]: Avg Loss: 0.9896, Total Train Accuracy: 67.4950, Total Test Accuracy: 67.6300
# Epoch [16/150]: Avg Loss: 0.9469, Total Train Accuracy: 69.1417, Total Test Accuracy: 70.2300
# Epoch [17/150]: Avg Loss: 0.9123, Total Train Accuracy: 70.3167, Total Test Accuracy: 70.8700
# Epoch [18/150]: Avg Loss: 0.8808, Total Train Accuracy: 71.6000, Total Test Accuracy: 72.7700
# Epoch [19/150]: Avg Loss: 0.8375, Total Train Accuracy: 73.1717, Total Test Accuracy: 73.4300
# Epoch [20/150]: Avg Loss: 0.8105, Total Train Accuracy: 73.6933, Total Test Accuracy: 73.8700
# Epoch [21/150]: Avg Loss: 0.7908, Total Train Accuracy: 74.7200, Total Test Accuracy: 75.3100
# Epoch [22/150]: Avg Loss: 0.7705, Total Train Accuracy: 75.1650, Total Test Accuracy: 76.3600
# Epoch [23/150]: Avg Loss: 0.7458, Total Train Accuracy: 76.1050, Total Test Accuracy: 76.6300
# Epoch [24/150]: Avg Loss: 0.7334, Total Train Accuracy: 76.4583, Total Test Accuracy: 77.0500
# Epoch [25/150]: Avg Loss: 0.7087, Total Train Accuracy: 77.3017, Total Test Accuracy: 77.3600
# Epoch [26/150]: Avg Loss: 0.6981, Total Train Accuracy: 77.7083, Total Test Accuracy: 78.3400
# Epoch [27/150]: Avg Loss: 0.6771, Total Train Accuracy: 78.3567, Total Test Accuracy: 78.6200
# Epoch [28/150]: Avg Loss: 0.6643, Total Train Accuracy: 78.7517, Total Test Accuracy: 78.6600
# Epoch [29/150]: Avg Loss: 0.6472, Total Train Accuracy: 79.3300, Total Test Accuracy: 79.7900
# Epoch [30/150]: Avg Loss: 0.6348, Total Train Accuracy: 79.7767, Total Test Accuracy: 80.7200
# Epoch [31/150]: Avg Loss: 0.6282, Total Train Accuracy: 79.7800, Total Test Accuracy: 81.2500
# Epoch [32/150]: Avg Loss: 0.6147, Total Train Accuracy: 80.3583, Total Test Accuracy: 81.0300
# Epoch [33/150]: Avg Loss: 0.5974, Total Train Accuracy: 80.8633, Total Test Accuracy: 80.8400
# Epoch [34/150]: Avg Loss: 0.5849, Total Train Accuracy: 81.2283, Total Test Accuracy: 81.5200
# Epoch [35/150]: Avg Loss: 0.5833, Total Train Accuracy: 81.4167, Total Test Accuracy: 81.6000
# Epoch [36/150]: Avg Loss: 0.5645, Total Train Accuracy: 82.0167, Total Test Accuracy: 81.8800
# Epoch [37/150]: Avg Loss: 0.5589, Total Train Accuracy: 82.2150, Total Test Accuracy: 82.8300
# Epoch [38/150]: Avg Loss: 0.5508, Total Train Accuracy: 82.5217, Total Test Accuracy: 83.0400
# Epoch [39/150]: Avg Loss: 0.5444, Total Train Accuracy: 82.7433, Total Test Accuracy: 82.9700
# Epoch [40/150]: Avg Loss: 0.5340, Total Train Accuracy: 83.0450, Total Test Accuracy: 82.7300
# Epoch [41/150]: Avg Loss: 0.5246, Total Train Accuracy: 83.1967, Total Test Accuracy: 83.1800
# Epoch [42/150]: Avg Loss: 0.5153, Total Train Accuracy: 83.6167, Total Test Accuracy: 83.7000
# Epoch [43/150]: Avg Loss: 0.5142, Total Train Accuracy: 83.6850, Total Test Accuracy: 83.5600
# Epoch [44/150]: Avg Loss: 0.5037, Total Train Accuracy: 84.0283, Total Test Accuracy: 84.2900
# Epoch [45/150]: Avg Loss: 0.4971, Total Train Accuracy: 84.1617, Total Test Accuracy: 84.3700
# Epoch [46/150]: Avg Loss: 0.4960, Total Train Accuracy: 84.2483, Total Test Accuracy: 84.4100
# Epoch [47/150]: Avg Loss: 0.4853, Total Train Accuracy: 84.7017, Total Test Accuracy: 84.5200
# Epoch [48/150]: Avg Loss: 0.4868, Total Train Accuracy: 84.6900, Total Test Accuracy: 84.8100
# Epoch [49/150]: Avg Loss: 0.4735, Total Train Accuracy: 85.1217, Total Test Accuracy: 84.8400
# Epoch [50/150]: Avg Loss: 0.4740, Total Train Accuracy: 85.0467, Total Test Accuracy: 85.0000
# Epoch [51/150]: Avg Loss: 0.4664, Total Train Accuracy: 85.1450, Total Test Accuracy: 85.0100
# Epoch [52/150]: Avg Loss: 0.4658, Total Train Accuracy: 85.2500, Total Test Accuracy: 85.2200
# Epoch [53/150]: Avg Loss: 0.4582, Total Train Accuracy: 85.5367, Total Test Accuracy: 86.0800
# Epoch [54/150]: Avg Loss: 0.4584, Total Train Accuracy: 85.5700, Total Test Accuracy: 85.8100
# Epoch [55/150]: Avg Loss: 0.4511, Total Train Accuracy: 85.7433, Total Test Accuracy: 85.8600
# Epoch [56/150]: Avg Loss: 0.4453, Total Train Accuracy: 85.9350, Total Test Accuracy: 85.9700
# Epoch [57/150]: Avg Loss: 0.4363, Total Train Accuracy: 86.0683, Total Test Accuracy: 85.5800
# Epoch [58/150]: Avg Loss: 0.4425, Total Train Accuracy: 85.9450, Total Test Accuracy: 85.8400
# Epoch [59/150]: Avg Loss: 0.4368, Total Train Accuracy: 86.2383, Total Test Accuracy: 85.5000
# Epoch [60/150]: Avg Loss: 0.4305, Total Train Accuracy: 86.2417, Total Test Accuracy: 85.9500
# Epoch [61/150]: Avg Loss: 0.4274, Total Train Accuracy: 86.3400, Total Test Accuracy: 86.0700
# Epoch [62/150]: Avg Loss: 0.4251, Total Train Accuracy: 86.5500, Total Test Accuracy: 85.9700
# Epoch [63/150]: Avg Loss: 0.4209, Total Train Accuracy: 86.6233, Total Test Accuracy: 86.6400
# Epoch [64/150]: Avg Loss: 0.4187, Total Train Accuracy: 86.7900, Total Test Accuracy: 86.6200
# Epoch [65/150]: Avg Loss: 0.4092, Total Train Accuracy: 86.9717, Total Test Accuracy: 86.7200
# Epoch [66/150]: Avg Loss: 0.4103, Total Train Accuracy: 86.8583, Total Test Accuracy: 86.9800
# Epoch [67/150]: Avg Loss: 0.4107, Total Train Accuracy: 87.0083, Total Test Accuracy: 87.0500
# Epoch [68/150]: Avg Loss: 0.4021, Total Train Accuracy: 87.0333, Total Test Accuracy: 87.2600
# Epoch [69/150]: Avg Loss: 0.4033, Total Train Accuracy: 87.2783, Total Test Accuracy: 86.7300
# Epoch [70/150]: Avg Loss: 0.3961, Total Train Accuracy: 87.1267, Total Test Accuracy: 87.4900
# Epoch [71/150]: Avg Loss: 0.4000, Total Train Accuracy: 87.1567, Total Test Accuracy: 87.1000
# Epoch [72/150]: Avg Loss: 0.3909, Total Train Accuracy: 87.6667, Total Test Accuracy: 87.5200
# Epoch [73/150]: Avg Loss: 0.3912, Total Train Accuracy: 87.6833, Total Test Accuracy: 87.3000
# Epoch [74/150]: Avg Loss: 0.3841, Total Train Accuracy: 87.8167, Total Test Accuracy: 87.4500
# Epoch [75/150]: Avg Loss: 0.3917, Total Train Accuracy: 87.5850, Total Test Accuracy: 87.6900
# Epoch [76/150]: Avg Loss: 0.3839, Total Train Accuracy: 87.8150, Total Test Accuracy: 87.7900
# Epoch [77/150]: Avg Loss: 0.3790, Total Train Accuracy: 88.0717, Total Test Accuracy: 87.6300
# Epoch [78/150]: Avg Loss: 0.3818, Total Train Accuracy: 87.8833, Total Test Accuracy: 87.8500
# Epoch [79/150]: Avg Loss: 0.3759, Total Train Accuracy: 88.1550, Total Test Accuracy: 87.6200
# Epoch [80/150]: Avg Loss: 0.3749, Total Train Accuracy: 87.9500, Total Test Accuracy: 87.7400
# Epoch [81/150]: Avg Loss: 0.3713, Total Train Accuracy: 88.1783, Total Test Accuracy: 88.5500
# Epoch [82/150]: Avg Loss: 0.3672, Total Train Accuracy: 88.3200, Total Test Accuracy: 87.8900
# Epoch [83/150]: Avg Loss: 0.3673, Total Train Accuracy: 88.3683, Total Test Accuracy: 88.0000
# Epoch [84/150]: Avg Loss: 0.3644, Total Train Accuracy: 88.3600, Total Test Accuracy: 87.9700
# Epoch [85/150]: Avg Loss: 0.3579, Total Train Accuracy: 88.5567, Total Test Accuracy: 88.4700
# Epoch [86/150]: Avg Loss: 0.3630, Total Train Accuracy: 88.4083, Total Test Accuracy: 88.6500
# Epoch [87/150]: Avg Loss: 0.3562, Total Train Accuracy: 88.5567, Total Test Accuracy: 87.8900
# Epoch [88/150]: Avg Loss: 0.3563, Total Train Accuracy: 88.6233, Total Test Accuracy: 88.1400
# Epoch [89/150]: Avg Loss: 0.3548, Total Train Accuracy: 88.6083, Total Test Accuracy: 88.3600
# Epoch [90/150]: Avg Loss: 0.3508, Total Train Accuracy: 88.8550, Total Test Accuracy: 87.9900
# Epoch [91/150]: Avg Loss: 0.3496, Total Train Accuracy: 88.8900, Total Test Accuracy: 88.2700
# Epoch [92/150]: Avg Loss: 0.3479, Total Train Accuracy: 89.1067, Total Test Accuracy: 88.7200
# Epoch [93/150]: Avg Loss: 0.3411, Total Train Accuracy: 89.1617, Total Test Accuracy: 88.4200
# Epoch [94/150]: Avg Loss: 0.3457, Total Train Accuracy: 89.0583, Total Test Accuracy: 88.7400
# Epoch [95/150]: Avg Loss: 0.3400, Total Train Accuracy: 89.1700, Total Test Accuracy: 88.7400
# Epoch [96/150]: Avg Loss: 0.3405, Total Train Accuracy: 89.0533, Total Test Accuracy: 88.6500
# Epoch [97/150]: Avg Loss: 0.3352, Total Train Accuracy: 89.3933, Total Test Accuracy: 89.0900
# Epoch [98/150]: Avg Loss: 0.3349, Total Train Accuracy: 89.2683, Total Test Accuracy: 88.9700
# Epoch [99/150]: Avg Loss: 0.3385, Total Train Accuracy: 89.2050, Total Test Accuracy: 88.5500
# Epoch [100/150]: Avg Loss: 0.3330, Total Train Accuracy: 89.2283, Total Test Accuracy: 88.6800
# Epoch [101/150]: Avg Loss: 0.3326, Total Train Accuracy: 89.3117, Total Test Accuracy: 89.0800
# Epoch [102/150]: Avg Loss: 0.3313, Total Train Accuracy: 89.5767, Total Test Accuracy: 88.6600
# Epoch [103/150]: Avg Loss: 0.3302, Total Train Accuracy: 89.5783, Total Test Accuracy: 88.8500
# Epoch [104/150]: Avg Loss: 0.3302, Total Train Accuracy: 89.5200, Total Test Accuracy: 89.3200
# Epoch [105/150]: Avg Loss: 0.3256, Total Train Accuracy: 89.6233, Total Test Accuracy: 89.2500
# Epoch [106/150]: Avg Loss: 0.3203, Total Train Accuracy: 89.6533, Total Test Accuracy: 89.3800
# Epoch [107/150]: Avg Loss: 0.3226, Total Train Accuracy: 89.6567, Total Test Accuracy: 88.8500
# Epoch [108/150]: Avg Loss: 0.3278, Total Train Accuracy: 89.5150, Total Test Accuracy: 88.9300
# Epoch [109/150]: Avg Loss: 0.3227, Total Train Accuracy: 89.6550, Total Test Accuracy: 89.2700
# Epoch [110/150]: Avg Loss: 0.3252, Total Train Accuracy: 89.7133, Total Test Accuracy: 89.3400
# Epoch [111/150]: Avg Loss: 0.3192, Total Train Accuracy: 89.6967, Total Test Accuracy: 89.2500
# Epoch [112/150]: Avg Loss: 0.3206, Total Train Accuracy: 89.6500, Total Test Accuracy: 89.2800
# Epoch [113/150]: Avg Loss: 0.3198, Total Train Accuracy: 89.6783, Total Test Accuracy: 89.1700
# Epoch [114/150]: Avg Loss: 0.3196, Total Train Accuracy: 89.7383, Total Test Accuracy: 89.2900
# Epoch [115/150]: Avg Loss: 0.3171, Total Train Accuracy: 89.8117, Total Test Accuracy: 89.5500
# Epoch [116/150]: Avg Loss: 0.3157, Total Train Accuracy: 89.7683, Total Test Accuracy: 89.4900
# Epoch [117/150]: Avg Loss: 0.3155, Total Train Accuracy: 89.8733, Total Test Accuracy: 89.0700
# Epoch [118/150]: Avg Loss: 0.3109, Total Train Accuracy: 90.0750, Total Test Accuracy: 89.3900
# Epoch [119/150]: Avg Loss: 0.3070, Total Train Accuracy: 90.0967, Total Test Accuracy: 89.4000
# Epoch [120/150]: Avg Loss: 0.3112, Total Train Accuracy: 89.9833, Total Test Accuracy: 89.7900
# Epoch [121/150]: Avg Loss: 0.3082, Total Train Accuracy: 89.9533, Total Test Accuracy: 90.0500
# Epoch [122/150]: Avg Loss: 0.3057, Total Train Accuracy: 90.1300, Total Test Accuracy: 89.0600
# Epoch [123/150]: Avg Loss: 0.3062, Total Train Accuracy: 90.2650, Total Test Accuracy: 89.2700
# Epoch [124/150]: Avg Loss: 0.3037, Total Train Accuracy: 90.3383, Total Test Accuracy: 89.1700
# Epoch [125/150]: Avg Loss: 0.3027, Total Train Accuracy: 90.3783, Total Test Accuracy: 89.8200
# Epoch [126/150]: Avg Loss: 0.3040, Total Train Accuracy: 90.3067, Total Test Accuracy: 89.5200
# Epoch [127/150]: Avg Loss: 0.3057, Total Train Accuracy: 90.2417, Total Test Accuracy: 89.9500
# Epoch [128/150]: Avg Loss: 0.2985, Total Train Accuracy: 90.4650, Total Test Accuracy: 89.9000
# Epoch [129/150]: Avg Loss: 0.3021, Total Train Accuracy: 90.4283, Total Test Accuracy: 89.6300
# Epoch [130/150]: Avg Loss: 0.2970, Total Train Accuracy: 90.5300, Total Test Accuracy: 89.7000
# Epoch [131/150]: Avg Loss: 0.3003, Total Train Accuracy: 90.3650, Total Test Accuracy: 89.6400
# Epoch [132/150]: Avg Loss: 0.2981, Total Train Accuracy: 90.4333, Total Test Accuracy: 89.8800
# Epoch [133/150]: Avg Loss: 0.2960, Total Train Accuracy: 90.4733, Total Test Accuracy: 89.7300
# Epoch [134/150]: Avg Loss: 0.2923, Total Train Accuracy: 90.6233, Total Test Accuracy: 89.7000
# Epoch [135/150]: Avg Loss: 0.2925, Total Train Accuracy: 90.6317, Total Test Accuracy: 90.0200
# Epoch [136/150]: Avg Loss: 0.2887, Total Train Accuracy: 90.6717, Total Test Accuracy: 89.7500
# Epoch [137/150]: Avg Loss: 0.2916, Total Train Accuracy: 90.6017, Total Test Accuracy: 89.2800
# Epoch [138/150]: Avg Loss: 0.2887, Total Train Accuracy: 90.6483, Total Test Accuracy: 90.1300
# Epoch [139/150]: Avg Loss: 0.2937, Total Train Accuracy: 90.6483, Total Test Accuracy: 89.9500
# Epoch [140/150]: Avg Loss: 0.2913, Total Train Accuracy: 90.7367, Total Test Accuracy: 90.0000
# Epoch [141/150]: Avg Loss: 0.2896, Total Train Accuracy: 90.6983, Total Test Accuracy: 89.7700
# Epoch [142/150]: Avg Loss: 0.2856, Total Train Accuracy: 90.6083, Total Test Accuracy: 90.2100
# Epoch [143/150]: Avg Loss: 0.2853, Total Train Accuracy: 90.7050, Total Test Accuracy: 90.2600
# Epoch [144/150]: Avg Loss: 0.2857, Total Train Accuracy: 90.8250, Total Test Accuracy: 90.0900
# Epoch [145/150]: Avg Loss: 0.2832, Total Train Accuracy: 90.9433, Total Test Accuracy: 89.8900
# Epoch [146/150]: Avg Loss: 0.2847, Total Train Accuracy: 90.8417, Total Test Accuracy: 90.3300
# Epoch [147/150]: Avg Loss: 0.2838, Total Train Accuracy: 90.9033, Total Test Accuracy: 89.6700
# Epoch [148/150]: Avg Loss: 0.2836, Total Train Accuracy: 90.9067, Total Test Accuracy: 90.1300
# Epoch [149/150]: Avg Loss: 0.2856, Total Train Accuracy: 90.8567, Total Test Accuracy: 90.3900
# Epoch [150/150]: Avg Loss: 0.2816, Total Train Accuracy: 90.9067, Total Test Accuracy: 90.1500

# %%
plt.plot(list(range(num_epochs)), total_train_acc, label=f'Train (Max: {max(total_train_acc):.4f}')
plt.plot(list(range(num_epochs)), total_test_acc, label=f'Test (Max:{max(total_test_acc):.4f}')
plt.title(f'{num_clients} Clients: Accuracy vs. Epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend()
plt.savefig(f'./Results/{num_clients} Clients Accuracy vs. Epochs.png', bbox_inches='tight')
plt.show()

# %%
# Test accuracy for each client
with torch.no_grad():
    n_correct = []
    n_samples = []
    test_acc = []
    for client in range(num_clients):
        images, labels = iter(test_loaders[client]).next()
        # images = images.reshape(-1, 784).to(device)
        images = images.to(device)
        labels = labels.to(device)

        ## Forward
        # Forward through starting layers (with client 1)
        activations1 = startModels[client](images)
        remote_activations1 = activations1.detach().requires_grad_(True) 

        # Forward through middle layers (with server) 
        activations2 = serverModel(remote_activations1)
        remote_activations2 = activations2.detach().requires_grad_(True)

        # Forward through ending layers (with client 1)
        outputs = endModels[client](remote_activations2)

        # value, index
        _, predicted = torch.max(outputs.data, 1)
        n_correct.append((predicted == labels).sum().item())
        n_samples.append(labels.size(0))
        test_acc.append(100.0 * n_correct[-1]/n_samples[-1])
        # print(f"Client {client}: {test_acc[-1]:.4f}")
    print(f'Total Test Accuracy: {100*sum(n_correct)/sum(n_samples)}')
plt.figure(figsize=(40, 7))
plt.xlabel('Client Number')
plt.ylabel(f'Accuracy (Avg: {100*sum(n_correct)/sum(n_samples):.4f})')
plt.title(f'{num_clients} Clients: Test Accuracy for each client')
plt.bar(list(range(num_clients)),test_acc)
plt.figtext(0.5, 0, f"Min: {min(test_acc):.2f}, Max: {max(test_acc):.2f}", ha="center", fontsize=15, bbox={"alpha":0.5, "pad":5})
plt.savefig(f'./Results/{num_clients} Test Accuracy for each client.png', bbox_inches='tight')
plt.show()
# Out:
# Total Test Accuracy: 90.01

# %%
# Train accuracy for each client
with torch.no_grad():
    n_correct = []
    n_samples = []
    train_acc = []
    for client in range(num_clients):
        images, labels = iter(train_loaders[client]).next()
        # images = images.reshape(-1, 784).to(device)
        images = images.to(device)
        labels = labels.to(device)

        ## Forward
        # Forward through starting layers (with client 1)
        activations1 = startModels[client](images)
        remote_activations1 = activations1.detach().requires_grad_(True) 

        # Forward through middle layers (with server) 
        activations2 = serverModel(remote_activations1)
        remote_activations2 = activations2.detach().requires_grad_(True)

        # Forward through ending layers (with client 1)
        outputs = endModels[client](remote_activations2)

        # value, index
        _, predicted = torch.max(outputs.data, 1)
        n_correct.append((predicted == labels).sum().item())
        n_samples.append(labels.size(0))
        train_acc.append(100.0 * n_correct[-1]/n_samples[-1])
        # print(f"Client {client}: {train_acc[-1]:.4f}")
    # print(f'Total Train Accuracy: {100*sum(n_correct)/sum(n_samples)}')
plt.figure(figsize=(40, 7))
plt.xlabel('Client Number')
plt.ylabel(f'Accuracy (Avg: {100*sum(n_correct)/sum(n_samples):.4f})')
plt.title(f'{num_clients} Clients: Train Accuracy for each client')
plt.bar(list(range(num_clients)),train_acc)
plt.figtext(0.5, 0, f"Min: {min(train_acc):.2f}, Max: {max(train_acc):.2f}", ha="center", fontsize=15, bbox={"alpha":0.5, "pad":5})
plt.savefig(f'./Results/{num_clients} Clients Train Accuracy for each client.png', bbox_inches='tight')
plt.show()
