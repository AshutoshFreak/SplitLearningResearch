# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# Hyper-parameters
input_size = 3
channels1 = 8
channels2 = 16
channels3 = 32
fc_size1 = 32*2*2
fc_size2 = 50
# fc_size3 = 84
num_classes = 10
num_epochs = 50
learning_rate = 0.01
batch_size = 64
# momentum = 0.9

# %%
# CIFAR10 dataset

# !wget https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# !tar -zxvf cifar-10-python.tar.gz ../../data

train_dataset = torchvision.datasets.CIFAR10(root='../../data', 
                                           train=True, 
                                           transform=transforms.ToTensor(),  
                                           download=True)

test_dataset = torchvision.datasets.CIFAR10(root='../../data', 
                                          train=False, 
                                          transform=transforms.ToTensor())

# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset, 
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset, 
                                          batch_size=batch_size, 
                                          shuffle=False)
classes = ('plane', 'car', 'bird', 'cat', 'deer', 
           'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified

# %%
examples = iter(test_loader)
example_data, example_targets = examples.next()

for i in range(6):
    plt.subplot(2,3,i+1)
    plt.title(classes[example_targets[i].item()])
    plt.imshow(example_data[i][0], cmap='gray')
plt.show()

# %%
# Fully connected neural network with two hidden layers
class CNN(nn.Module):
    def __init__(self, input_size, channels1, channels2, channels3, fc_size1, fc_size2, num_classes):
        super(CNN, self).__init__()
        # self.conv1 = nn.Conv2d(input_size, channels1, kernel_size=5)
        # self.pool = nn.MaxPool2d(2, 2)
        # self.conv2 = nn.Conv2d(channels1, channels2, kernel_size=5)
        # self.fc1 = nn.Linear(fc_size1, fc_size2)
        # self.fc2 = nn.Linear(fc_size2, fc_size3)
        # self.fc3 = nn.Linear(fc_size3, num_classes)
        self.conv1 = nn.Conv2d(input_size, channels1, kernel_size=5, stride=1)
        self.conv2 = nn.Conv2d(channels1, channels2, kernel_size=3, stride=1)
        self.conv3 = nn.Conv2d(channels2, channels3, kernel_size=3, stride=1)
        self.fc1 = nn.Linear(fc_size1, fc_size2)
        self.fc2 = nn.Linear(fc_size2, num_classes)
        # self.fc_size1 = fc_size1


    def forward(self, x):
        # x = self.conv1(x)
        # x = F.relu(x)
        # x = self.pool(x)
        # x = self.conv2(x)
        # x = F.relu(x)
        # x = self.pool(x)
        # x = x.view(-1, fc_size1) # Flatten
        # x = self.fc1(x)
        # x = F.relu(x)
        # x = self.fc2(x)
        # x = F.relu(x)
        # x = self.fc3(x)
        x = self.conv1(x)
        x = F.max_pool2d(x, 2)
        x = F.relu(x)
        x = self.conv2(x)
        x = F.max_pool2d(x, 2)
        x = F.relu(x)
        x = self.conv3(x)
        x = F.max_pool2d(x, 2)
        x = F.relu(x)
        x = x.view(-1, fc_size1) # Flatten
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        # no activation and no softmax at the end
        return x

model = CNN(input_size, channels1, channels2, channels3, fc_size1, fc_size2, num_classes).to(device)

# %%
# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=0.9)

# %%
# Train the model
n_total_steps = len(train_loader)
train_acc = []
test_acc = []
for epoch in range(num_epochs):
    n_correct = 0
    n_samples = 0
    for i, (images, labels) in enumerate(train_loader):  
        # original shape: [100, 1, 28, 28]
        # resized: [100, 784]
        # print(images.shape)
        images = images.to(device)
        labels = labels.to(device)
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)

        # Calculating Train Accuracy
        if i == 0:
            with torch.no_grad():
                n_correct = 0
                n_samples = 0
                for images, labels in train_loader:
                    images = images.to(device)
                    labels = labels.to(device)
                    outputs = model(images)
                    _, predicted = torch.max(outputs.data, 1)
                    n_correct += (predicted == labels).sum().item()
                    n_samples += labels.size(0)
                train_acc.append(100*n_correct/n_samples)

            with torch.no_grad():
                n_correct = 0
                n_samples = 0
                for images, labels in test_loader:
                    images = images.to(device)
                    labels = labels.to(device)
                    outputs = model(images)
                    # max returns (value ,index)
                    _, predicted = torch.max(outputs.data, 1)
                    n_samples += labels.size(0)
                    n_correct += (predicted == labels).sum().item()
                test_acc.append(100.0 * n_correct / n_samples)

        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (i+1) % 100 == 0:
            print (f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():.4f}')
        if(i == 0):
            print(f'Train Accuracy: {train_acc[-1]}, Test Accuracy: {test_acc[-1]}')
# Out:
# Train Accuracy: 10.0, Test Accuracy: 10.0
# Epoch [1/50], Step [100/782], Loss: 2.3010
# Epoch [1/50], Step [200/782], Loss: 2.2954
# Epoch [1/50], Step [300/782], Loss: 2.2847
# Epoch [1/50], Step [400/782], Loss: 2.0771
# Epoch [1/50], Step [500/782], Loss: 2.0922
# Epoch [1/50], Step [600/782], Loss: 2.0436
# Epoch [1/50], Step [700/782], Loss: 1.8221
# Train Accuracy: 30.228, Test Accuracy: 30.07
# Epoch [2/50], Step [100/782], Loss: 1.7299
# Epoch [2/50], Step [200/782], Loss: 1.8152
# Epoch [2/50], Step [300/782], Loss: 1.6374
# Epoch [2/50], Step [400/782], Loss: 1.4973
# Epoch [2/50], Step [500/782], Loss: 1.4991
# Epoch [2/50], Step [600/782], Loss: 1.4314
# Epoch [2/50], Step [700/782], Loss: 1.5830
# Train Accuracy: 44.502, Test Accuracy: 43.89
# Epoch [3/50], Step [100/782], Loss: 1.4416
# Epoch [3/50], Step [200/782], Loss: 1.5685
# Epoch [3/50], Step [300/782], Loss: 1.2717
# Epoch [3/50], Step [400/782], Loss: 1.4068
# Epoch [3/50], Step [500/782], Loss: 1.3599
# Epoch [3/50], Step [600/782], Loss: 1.5883
# Epoch [3/50], Step [700/782], Loss: 1.4350
# Train Accuracy: 49.488, Test Accuracy: 47.77
# Epoch [4/50], Step [100/782], Loss: 1.5451
# Epoch [4/50], Step [200/782], Loss: 1.0671
# Epoch [4/50], Step [300/782], Loss: 1.2883
# Epoch [4/50], Step [400/782], Loss: 1.4382
# Epoch [4/50], Step [500/782], Loss: 1.3742
# Epoch [4/50], Step [600/782], Loss: 1.3255
# Epoch [4/50], Step [700/782], Loss: 1.3364
# Train Accuracy: 54.926, Test Accuracy: 52.9
# Epoch [5/50], Step [100/782], Loss: 1.1269
# Epoch [5/50], Step [200/782], Loss: 1.2620
# Epoch [5/50], Step [300/782], Loss: 1.0654
# Epoch [5/50], Step [400/782], Loss: 1.2827
# Epoch [5/50], Step [500/782], Loss: 1.4723
# Epoch [5/50], Step [600/782], Loss: 1.0921
# Epoch [5/50], Step [700/782], Loss: 1.1843
# Train Accuracy: 55.258, Test Accuracy: 52.91
# Epoch [6/50], Step [100/782], Loss: 1.1476
# Epoch [6/50], Step [200/782], Loss: 1.1580
# Epoch [6/50], Step [300/782], Loss: 1.4734
# Epoch [6/50], Step [400/782], Loss: 1.0650
# Epoch [6/50], Step [500/782], Loss: 1.0082
# Epoch [6/50], Step [600/782], Loss: 1.2930
# Epoch [6/50], Step [700/782], Loss: 1.4266
# Train Accuracy: 59.054, Test Accuracy: 55.69
# Epoch [7/50], Step [100/782], Loss: 1.1248
# Epoch [7/50], Step [200/782], Loss: 1.1890
# Epoch [7/50], Step [300/782], Loss: 1.1508
# Epoch [7/50], Step [400/782], Loss: 1.2830
# Epoch [7/50], Step [500/782], Loss: 1.1748
# Epoch [7/50], Step [600/782], Loss: 0.9146
# Epoch [7/50], Step [700/782], Loss: 1.3409
# Train Accuracy: 58.42, Test Accuracy: 55.7
# Epoch [8/50], Step [100/782], Loss: 1.6384
# Epoch [8/50], Step [200/782], Loss: 1.0165
# Epoch [8/50], Step [300/782], Loss: 1.0515
# Epoch [8/50], Step [400/782], Loss: 1.0841
# Epoch [8/50], Step [500/782], Loss: 1.3534
# Epoch [8/50], Step [600/782], Loss: 1.2371
# Epoch [8/50], Step [700/782], Loss: 1.2015
# Train Accuracy: 59.84, Test Accuracy: 56.6
# Epoch [9/50], Step [100/782], Loss: 1.1513
# Epoch [9/50], Step [200/782], Loss: 1.3174
# Epoch [9/50], Step [300/782], Loss: 0.9443
# Epoch [9/50], Step [400/782], Loss: 1.0626
# Epoch [9/50], Step [500/782], Loss: 1.2197
# Epoch [9/50], Step [600/782], Loss: 1.1930
# Epoch [9/50], Step [700/782], Loss: 1.1347
# Train Accuracy: 60.264, Test Accuracy: 56.78
# Epoch [10/50], Step [100/782], Loss: 1.0103
# Epoch [10/50], Step [200/782], Loss: 1.1200
# Epoch [10/50], Step [300/782], Loss: 1.1761
# Epoch [10/50], Step [400/782], Loss: 1.3409
# Epoch [10/50], Step [500/782], Loss: 0.9985
# Epoch [10/50], Step [600/782], Loss: 1.3293
# Epoch [10/50], Step [700/782], Loss: 1.1585
# Train Accuracy: 61.438, Test Accuracy: 57.48
# Epoch [11/50], Step [100/782], Loss: 0.9201
# Epoch [11/50], Step [200/782], Loss: 0.8537
# Epoch [11/50], Step [300/782], Loss: 1.1449
# Epoch [11/50], Step [400/782], Loss: 1.3368
# Epoch [11/50], Step [500/782], Loss: 1.1257
# Epoch [11/50], Step [600/782], Loss: 0.8361
# Epoch [11/50], Step [700/782], Loss: 0.9822
# Train Accuracy: 62.312, Test Accuracy: 58.42
# Epoch [12/50], Step [100/782], Loss: 1.2346
# Epoch [12/50], Step [200/782], Loss: 0.8551
# Epoch [12/50], Step [300/782], Loss: 1.1248
# Epoch [12/50], Step [400/782], Loss: 0.7761
# Epoch [12/50], Step [500/782], Loss: 1.1762
# Epoch [12/50], Step [600/782], Loss: 1.2208
# Epoch [12/50], Step [700/782], Loss: 1.1536
# Train Accuracy: 65.512, Test Accuracy: 60.6
# Epoch [13/50], Step [100/782], Loss: 1.0076
# Epoch [13/50], Step [200/782], Loss: 1.1783
# Epoch [13/50], Step [300/782], Loss: 1.3782
# Epoch [13/50], Step [400/782], Loss: 1.0058
# Epoch [13/50], Step [500/782], Loss: 0.9042
# Epoch [13/50], Step [600/782], Loss: 0.9415
# Epoch [13/50], Step [700/782], Loss: 0.9846
# Train Accuracy: 65.074, Test Accuracy: 61.2
# Epoch [14/50], Step [100/782], Loss: 1.0881
# Epoch [14/50], Step [200/782], Loss: 1.1843
# Epoch [14/50], Step [300/782], Loss: 1.1161
# Epoch [14/50], Step [400/782], Loss: 0.9672
# Epoch [14/50], Step [500/782], Loss: 0.8075
# Epoch [14/50], Step [600/782], Loss: 0.8996
# Epoch [14/50], Step [700/782], Loss: 0.8141
# Train Accuracy: 67.11, Test Accuracy: 62.4
# Epoch [15/50], Step [100/782], Loss: 0.7789
# Epoch [15/50], Step [200/782], Loss: 1.3052
# Epoch [15/50], Step [300/782], Loss: 1.0081
# Epoch [15/50], Step [400/782], Loss: 1.2465
# Epoch [15/50], Step [500/782], Loss: 1.2098
# Epoch [15/50], Step [600/782], Loss: 0.8254
# Epoch [15/50], Step [700/782], Loss: 0.7636
# Train Accuracy: 64.962, Test Accuracy: 60.19
# Epoch [16/50], Step [100/782], Loss: 0.9741
# Epoch [16/50], Step [200/782], Loss: 0.8475
# Epoch [16/50], Step [300/782], Loss: 0.9200
# Epoch [16/50], Step [400/782], Loss: 1.0094
# Epoch [16/50], Step [500/782], Loss: 0.7435
# Epoch [16/50], Step [600/782], Loss: 0.9585
# Epoch [16/50], Step [700/782], Loss: 0.8664
# Train Accuracy: 66.138, Test Accuracy: 60.61
# Epoch [17/50], Step [100/782], Loss: 0.9680
# Epoch [17/50], Step [200/782], Loss: 1.1730
# Epoch [17/50], Step [300/782], Loss: 1.1983
# Epoch [17/50], Step [400/782], Loss: 0.8585
# Epoch [17/50], Step [500/782], Loss: 1.0656
# Epoch [17/50], Step [600/782], Loss: 1.1451
# Epoch [17/50], Step [700/782], Loss: 1.0342
# Train Accuracy: 67.606, Test Accuracy: 61.71
# Epoch [18/50], Step [100/782], Loss: 0.8439
# Epoch [18/50], Step [200/782], Loss: 0.9586
# Epoch [18/50], Step [300/782], Loss: 1.0962
# Epoch [18/50], Step [400/782], Loss: 0.9634
# Epoch [18/50], Step [500/782], Loss: 0.8453
# Epoch [18/50], Step [600/782], Loss: 0.7567
# Epoch [18/50], Step [700/782], Loss: 0.8717
# Train Accuracy: 68.57, Test Accuracy: 62.63
# Epoch [19/50], Step [100/782], Loss: 0.9966
# Epoch [19/50], Step [200/782], Loss: 0.8519
# Epoch [19/50], Step [300/782], Loss: 0.7961
# Epoch [19/50], Step [400/782], Loss: 1.1635
# Epoch [19/50], Step [500/782], Loss: 0.9945
# Epoch [19/50], Step [600/782], Loss: 0.8879
# Epoch [19/50], Step [700/782], Loss: 0.9847
# Train Accuracy: 67.72, Test Accuracy: 61.71
# Epoch [20/50], Step [100/782], Loss: 0.9397
# Epoch [20/50], Step [200/782], Loss: 1.1088
# Epoch [20/50], Step [300/782], Loss: 1.1249
# Epoch [20/50], Step [400/782], Loss: 1.1788
# Epoch [20/50], Step [500/782], Loss: 0.6489
# Epoch [20/50], Step [600/782], Loss: 0.7988
# Epoch [20/50], Step [700/782], Loss: 0.8470
# Train Accuracy: 68.188, Test Accuracy: 62.43
# Epoch [21/50], Step [100/782], Loss: 0.7885
# Epoch [21/50], Step [200/782], Loss: 0.8083
# Epoch [21/50], Step [300/782], Loss: 1.1455
# Epoch [21/50], Step [400/782], Loss: 0.9728
# Epoch [21/50], Step [500/782], Loss: 1.1563
# Epoch [21/50], Step [600/782], Loss: 0.9315
# Epoch [21/50], Step [700/782], Loss: 0.8425
# Train Accuracy: 67.934, Test Accuracy: 61.82
# Epoch [22/50], Step [100/782], Loss: 1.0320
# Epoch [22/50], Step [200/782], Loss: 0.8170
# Epoch [22/50], Step [300/782], Loss: 0.7360
# Epoch [22/50], Step [400/782], Loss: 1.0580
# Epoch [22/50], Step [500/782], Loss: 0.9627
# Epoch [22/50], Step [600/782], Loss: 1.0214
# Epoch [22/50], Step [700/782], Loss: 0.7947
# Train Accuracy: 69.676, Test Accuracy: 63.01
# Epoch [23/50], Step [100/782], Loss: 1.0285
# Epoch [23/50], Step [200/782], Loss: 0.8502
# Epoch [23/50], Step [300/782], Loss: 1.0114
# Epoch [23/50], Step [400/782], Loss: 0.9564
# Epoch [23/50], Step [500/782], Loss: 0.7457
# Epoch [23/50], Step [600/782], Loss: 0.7586
# Epoch [23/50], Step [700/782], Loss: 1.0667
# Train Accuracy: 67.468, Test Accuracy: 61.23
# Epoch [24/50], Step [100/782], Loss: 0.6152
# Epoch [24/50], Step [200/782], Loss: 0.9144
# Epoch [24/50], Step [300/782], Loss: 0.8495
# Epoch [24/50], Step [400/782], Loss: 0.8277
# Epoch [24/50], Step [500/782], Loss: 0.8401
# Epoch [24/50], Step [600/782], Loss: 1.0679
# Epoch [24/50], Step [700/782], Loss: 0.9323
# Train Accuracy: 69.154, Test Accuracy: 63.04
# Epoch [25/50], Step [100/782], Loss: 1.0013
# Epoch [25/50], Step [200/782], Loss: 1.1561
# Epoch [25/50], Step [300/782], Loss: 0.8402
# Epoch [25/50], Step [400/782], Loss: 0.8703
# Epoch [25/50], Step [500/782], Loss: 0.8829
# Epoch [25/50], Step [600/782], Loss: 1.0500
# Epoch [25/50], Step [700/782], Loss: 1.0162
# Train Accuracy: 68.012, Test Accuracy: 62.0
# Epoch [26/50], Step [100/782], Loss: 1.0092
# Epoch [26/50], Step [200/782], Loss: 0.8388
# Epoch [26/50], Step [300/782], Loss: 0.9384
# Epoch [26/50], Step [400/782], Loss: 0.6447
# Epoch [26/50], Step [500/782], Loss: 0.8864
# Epoch [26/50], Step [600/782], Loss: 1.0496
# Epoch [26/50], Step [700/782], Loss: 0.8396
# Train Accuracy: 67.94, Test Accuracy: 61.99
# Epoch [27/50], Step [100/782], Loss: 1.0254
# Epoch [27/50], Step [200/782], Loss: 0.6621
# Epoch [27/50], Step [300/782], Loss: 0.6644
# Epoch [27/50], Step [400/782], Loss: 0.7174
# Epoch [27/50], Step [500/782], Loss: 0.8401
# Epoch [27/50], Step [600/782], Loss: 1.1666
# Epoch [27/50], Step [700/782], Loss: 0.9476
# Train Accuracy: 71.608, Test Accuracy: 64.64
# Epoch [28/50], Step [100/782], Loss: 0.9016
# Epoch [28/50], Step [200/782], Loss: 0.9793
# Epoch [28/50], Step [300/782], Loss: 0.8181
# Epoch [28/50], Step [400/782], Loss: 1.0353
# Epoch [28/50], Step [500/782], Loss: 1.1311
# Epoch [28/50], Step [600/782], Loss: 0.7697
# Epoch [28/50], Step [700/782], Loss: 1.2407
# Train Accuracy: 71.942, Test Accuracy: 64.49
# Epoch [29/50], Step [100/782], Loss: 0.8461
# Epoch [29/50], Step [200/782], Loss: 0.9040
# Epoch [29/50], Step [300/782], Loss: 0.6994
# Epoch [29/50], Step [400/782], Loss: 0.8508
# Epoch [29/50], Step [500/782], Loss: 0.9655
# Epoch [29/50], Step [600/782], Loss: 1.0055
# Epoch [29/50], Step [700/782], Loss: 0.9507
# Train Accuracy: 71.068, Test Accuracy: 63.96
# Epoch [30/50], Step [100/782], Loss: 0.7463
# Epoch [30/50], Step [200/782], Loss: 0.7866
# Epoch [30/50], Step [300/782], Loss: 0.7760
# Epoch [30/50], Step [400/782], Loss: 0.8454
# Epoch [30/50], Step [500/782], Loss: 0.9197
# Epoch [30/50], Step [600/782], Loss: 0.8524
# Epoch [30/50], Step [700/782], Loss: 0.7799
# Train Accuracy: 70.544, Test Accuracy: 63.19
# Epoch [31/50], Step [100/782], Loss: 1.1240
# Epoch [31/50], Step [200/782], Loss: 1.0657
# Epoch [31/50], Step [300/782], Loss: 0.9092
# Epoch [31/50], Step [400/782], Loss: 0.6981
# Epoch [31/50], Step [500/782], Loss: 1.0537
# Epoch [31/50], Step [600/782], Loss: 1.1196
# Epoch [31/50], Step [700/782], Loss: 0.7964
# Train Accuracy: 68.712, Test Accuracy: 62.05
# Epoch [32/50], Step [100/782], Loss: 0.9144
# Epoch [32/50], Step [200/782], Loss: 0.6700
# Epoch [32/50], Step [300/782], Loss: 1.1385
# Epoch [32/50], Step [400/782], Loss: 0.7899
# Epoch [32/50], Step [500/782], Loss: 1.0527
# Epoch [32/50], Step [600/782], Loss: 1.0489
# Epoch [32/50], Step [700/782], Loss: 0.5107
# Train Accuracy: 71.226, Test Accuracy: 63.41
# Epoch [33/50], Step [100/782], Loss: 0.8725
# Epoch [33/50], Step [200/782], Loss: 0.8916
# Epoch [33/50], Step [300/782], Loss: 0.8413
# Epoch [33/50], Step [400/782], Loss: 0.9948
# Epoch [33/50], Step [500/782], Loss: 0.8944
# Epoch [33/50], Step [600/782], Loss: 0.7102
# Epoch [33/50], Step [700/782], Loss: 0.7299
# Train Accuracy: 71.006, Test Accuracy: 62.93
# Epoch [34/50], Step [100/782], Loss: 0.7736
# Epoch [34/50], Step [200/782], Loss: 0.9047
# Epoch [34/50], Step [300/782], Loss: 1.0287
# Epoch [34/50], Step [400/782], Loss: 0.7951
# Epoch [34/50], Step [500/782], Loss: 0.8878
# Epoch [34/50], Step [600/782], Loss: 0.7853
# Epoch [34/50], Step [700/782], Loss: 1.0523
# Train Accuracy: 71.45, Test Accuracy: 63.56
# Epoch [35/50], Step [100/782], Loss: 0.8399
# Epoch [35/50], Step [200/782], Loss: 0.9460
# Epoch [35/50], Step [300/782], Loss: 0.9719
# Epoch [35/50], Step [400/782], Loss: 0.8043
# Epoch [35/50], Step [500/782], Loss: 0.9673
# Epoch [35/50], Step [600/782], Loss: 0.6953
# Epoch [35/50], Step [700/782], Loss: 0.7442
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-b26ad78dcede> in <module>
#      22                 n_correct = 0
#      23                 n_samples = 0
# ---> 24                 for images, labels in train_loader:
#      25                     images = images.to(device)
#      26                     labels = labels.to(device)
#
# ~/venvs/torch/syft-0.2.x/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     343
#     344     def __next__(self):
# --> 345         data = self._next_data()
#     346         self._num_yielded += 1
#     347         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/venvs/torch/syft-0.2.x/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#     383     def _next_data(self):
#     384         index = self._next_index()  # may raise StopIteration
# --> 385         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     386         if self._pin_memory:
#     387             data = _utils.pin_memory.pin_memory(data)
#
# ~/venvs/torch/syft-0.2.x/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/venvs/torch/syft-0.2.x/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      42     def fetch(self, possibly_batched_index):
#      43         if self.auto_collation:
# ---> 44             data = [self.dataset[idx] for idx in possibly_batched_index]
#      45         else:
#      46             data = self.dataset[possibly_batched_index]
#
# ~/venvs/torch/syft-0.2.x/lib/python3.8/site-packages/torchvision/datasets/cifar.py in __getitem__(self, index)
#     120         # doing this so that it is consistent with all other datasets
#     121         # to return a PIL Image
# --> 122         img = Image.fromarray(img)
#     123
#     124         if self.transform is not None:
#
# ~/venvs/torch/syft-0.2.x/lib/python3.8/site-packages/PIL/Image.py in fromarray(obj, mode)
#    2779     if strides is not None:
#    2780         if hasattr(obj, "tobytes"):
# -> 2781             obj = obj.tobytes()
#    2782         else:
#    2783             obj = obj.tostring()
#
# KeyboardInterrupt:

# %%
# plt.plot(list(range(len(acc))), acc, label=f'Train (Max: {max(total_train_acc):.4f}')
# plt.show()
plt.plot(list(range(len(train_acc))), train_acc, label=f'Train (Max: {max(train_acc):.4f}')
plt.plot(list(range(len(test_acc))), test_acc, label=f'Test (Max:{max(test_acc):.4f}')
# plt.title(f'{num_clients} Clients: Accuracy vs. Epochs')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend()
# plt.savefig(f'./Results/{num_clients} Clients Accuracy vs. Epochs.png', bbox_inches='tight')
plt.show()

# %%
# Test the model
with torch.no_grad():
    n_correct = 0
    n_samples = 0
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        # max returns (value ,index)
        _, predicted = torch.max(outputs.data, 1)
        n_samples += labels.size(0)
        n_correct += (predicted == labels).sum().item()

    acc = 100.0 * n_correct / n_samples
    print(f'Accuracy of the network on the 10000 test images: {acc} %')
# Out:
# Accuracy of the network on the 10000 test images: 63.1 %
